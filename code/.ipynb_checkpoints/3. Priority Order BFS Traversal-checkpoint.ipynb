# %%
from skimage import data, io, segmentation, color, measure
from skimage.future import graph
from matplotlib import pyplot as plt
import cv2
import numpy as np
from skimage import draw
import networkx as nx
import pickle
from functools import reduce
from IPython.core.debugger import set_trace
# %matplotlib inline

# %%
with open('graphs.file', 'rb') as graphs_file:
    graphs = pickle.load(graphs_file)
print(f"{len(graphs)} graphs loaded from file.")
# Out:
# 1280 graphs loaded from file.

# %%
gg = graphs[0]

# %%
def get_max_degree_node(graph):
    max_degree = 0
    max_degree_node = None
    
    for degree in graph.degree:
        if degree[1] > max_degree:
            max_degree = degree[1]
            max_degree_node = degree[0]
    
    return max_degree_node

# %%
error_graphs = []
def priority_bfs(graph, root):
    if root is None:
        return [(1,40000)]
    vector  = []
    visited = []
    queue   = []
    
    visited.append(root)
    queue.append(root)
    
    #set_trace()
    
    while queue:
        current_node = queue.pop(0)
        try:
            vector.append((current_node, graph.nodes()[current_node]['pixel count']))
        except Exception as e:
            print("xxxxxxxxxxxxxxxxxxxxx")
            print(root)
            print(e)
            error_graphs.append(graph)
            set_trace()
            return ""
            #nx.draw_networkx(graph)
        
        # populating neigbors of the current node 
        # and sorting them based on size

        current_node_neighbors = []
        current_node_neighbors_with_size = []
        for neighbor in graph.neighbors(current_node):
            current_node_neighbors_with_size.append((neighbor, graph.nodes()[current_node]['pixel count']))
        current_node_neighbors_with_size.sort(key = lambda x: x[1])
        for i in current_node_neighbors_with_size:
            current_node_neighbors.append(i[0])
            
            
        for neighbor in current_node_neighbors:
            if neighbor not in visited:
                visited.append(neighbor)
                queue.append(neighbor)
                
    return vector

# %%
vectors = []
for graph in graphs:
    # set the node with the highest edges as root
    root = get_max_degree_node(graph)
    
    # get BFS vector
    vector = priority_bfs(graph, root)
    vectors.append(vector)

# %%
# normalize dimension of all vectores
max_dimensions = max((map(len, vectors)))

new_vectors = []
for i in vectors:
    vector = [j[1] for j in i]
    vector += [0]*(max_dimensions-len(i))
    new_vectors.append(np.array(vector))

# %%
D = []
for vector_1 in new_vectors:
    D_row = []
    for vector_2 in new_vectors:
        diff = np.linalg.norm((vector_1 - vector_2), ord=1)
        D_row.append(diff)
    D.append(D_row)

# %%
a = np.asarray(D)
np.savetxt("bfs_D.csv", a, delimiter=",")

# %% [markdown]
# #### Setting node size

# %%
node_size = [i[1]['pixel count'] for i in gg.nodes(data=True)]
sum_node_size = sum(node_size)
node_size_normalized = [(i/sum_node_size)*5000 for i in node_size]

# %% [markdown]
# #### Setting node colors

# %%
node_color = []

for i in gg.nodes(data=True):
    current_color = i[1]['mean color']
    if np.array_equal(current_color, np.array([1,1,1])):
        # this is white
        # set to light grey
        node_color.append(np.array([0.7,0.7,0.7]))
    elif np.array_equal(current_color, np.array([2,2,2])):
        # this is black
        # set to dark grey
        node_color.append(np.array([0.3,0.3,0.3]))
    else:
        # this should never happen
        print("Unknown color of node.")

# %% [markdown]
# #### Setting node label

# %%
node_labels = {}
for index, size in enumerate(node_size):
    node_labels[index+1] = size

# %%
trajectory_names = {
    0:"BR0.5-CHI2.4",
    1:"BR0.5-CHI2.6",
    2:"BR0.5-CHI2.8",
    3:"BR0.5-CHI3.0",
    4:"BR0.52-CHI2.4",
    5:"BR0.52-CHI2.6",
    6:"BR0.52-CHI2.8",
    7:"BR0.52-CHI3.0",
    8:"BR0.54-CHI2.4",
    9:"BR0.54-CHI2.6",
    10:"BR0.54-CHI2.8",
    11:"BR0.54-CHI3.0",
    12:"BR0.56-CHI2.4",
    13:"BR0.56-CHI2.6",
    14:"BR0.56-CHI2.8",
    15:"BR0.56-CHI3.0",
}

# %%
for index,gg in enumerate(graphs[:2]):
    # setting node size
    node_size = [i[1]['pixel count'] for i in gg.nodes(data=True)]
    sum_node_size = sum(node_size)
    node_size_normalized = [(i/sum_node_size)*5000 for i in node_size]
    
    # setting node color
    node_color = []

    for i in gg.nodes(data=True):
        current_color = i[1]['mean color']
        if np.array_equal(current_color, np.array([1,1,1])):
            # this is white
            # set to light grey
            node_color.append(np.array([0.7,0.7,0.7]))
        elif np.array_equal(current_color, np.array([2,2,2])):
            # this is black
            # set to dark grey
            node_color.append(np.array([0.3,0.3,0.3]))
        else:
            # this should never happen
            print("Unknown color of node.")
    
    # setting node label
    node_labels = {}
    for index, size in enumerate(node_size):
        node_labels[index+1] = size
        
    # create the graph and save it
    fig,axes = plt.subplots()
    aa = nx.draw_kamada_kawai(gg, 
                         node_size   = node_size_normalized, 
                         node_color  = node_color,
                         edgecolors  = 'k',
                         labels      = node_labels,
                         label       = "ABCD",
                         with_labels = True,
                         ax          = axes)
    title = trajectory_names[index//80]+f" #{index} ({index})"
    plt.title(title, y=-0.1)
    plt.savefig(f"{title}.png", format="PNG")

# %%
fig,axes = plt.subplots()
nx.draw_kamada_kawai(gg, 
                     node_size   = node_size_normalized, 
                     node_color  = node_color,
                     edgecolors  = 'k',
                     labels      = node_labels,
                     label       = "ABCD",
                     with_labels = True,
                     ax          = axes)
plt.title('BR0.5CHI9.0', y=-0.1)
plt.savefig("Graph.png", format="PNG")
